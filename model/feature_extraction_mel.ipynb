# %%
import pandas as pd
import numpy as np

import sys
import librosa
import librosa.display

from sklearn.model_selection import train_test_split

# to play the audio files
from IPython.display import Audio

import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# ## Load Datasets

# %%
emofilm_uk_df = pd.read_csv(
    'D:/Programming/nn/emotion_classification/datasets/emofilm_uk_df.csv')
emofilm_df = pd.read_csv(
    'D:/Programming/nn/emotion_classification/datasets/emofilm_df.csv')
uk_new_df = pd.read_csv(
    'D:/Programming/nn/emotion_classification/datasets/emofilm_uk_new_df.csv'
)
uk_new_test_df = pd.read_csv(
    'D:/Programming/nn/emotion_classification/datasets/emofilm_uk_new_test_df.csv'
)
ravdess_df = pd.read_csv(
    'D:/Programming/nn/emotion_classification/datasets/ravdess_df.csv')
savee_df = pd.read_csv(
    'D:/Programming/nn/emotion_classification/datasets/savee_df.csv')
tess_df = pd.read_csv(
    'D:/Programming/nn/emotion_classification/datasets/tess_df.csv')
cremad_df = pd.read_csv(
    'D:/Programming/nn/emotion_classification/datasets/cremad_df.csv')

# %%
data_df = pd.concat([emofilm_uk_df, emofilm_df, ravdess_df, savee_df, tess_df, cremad_df],
                    axis=0, ignore_index=True)
data_df_no_uk = pd.concat([ravdess_df, emofilm_df, savee_df, tess_df, cremad_df], #emofilm_df, savee_df, tess_df, cremad_df
                          axis=0, ignore_index=True)
data_df_uk = pd.concat([emofilm_uk_df, uk_new_df])

# %%
data_df['emotion'].replace('calm', 'neutral', inplace=True)
data_df_no_uk['emotion'].replace('calm', 'neutral', inplace=True)
data_df_uk['emotion'].replace('calm', 'neutral', inplace=True)
uk_new_df['emotion'].replace('calm', 'neutral', inplace=True)
uk_new_test_df['emotion'].replace('calm', 'neutral', inplace=True)

# %% [markdown]
# ### load data

# %%
length_2s = 2 * 22050

# %%
import load_utils as lu

# %%
combined_values, combined_labels = lu.load_and_scale(data_df_no_uk, length_2s, scale=True)
print(combined_values.shape, combined_labels)
# Out:
# 22050
# (13277, 44100) ['neutral' 'neutral' 'neutral' ... 'happiness' 'neutral' 'sadness']

# %%
uk_values, uk_labels = lu.load_and_scale(data_df_uk, length_2s, scale=True)
print(uk_values.shape)
uk_test_values, uk_test_labels = lu.load_and_scale(uk_new_test_df, length_2s, scale=True)
print(uk_test_values.shape)
# Out:
# 22050
# (111, 44100)
# 22050
# (41, 44100)

# %%
Audio(uk_test_values[1], rate=22050)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
x_train, x_test, y_train, y_test = train_test_split(
    combined_values, combined_labels, test_size=0.2, random_state=13)
x_val, x_test, y_val, y_test = train_test_split(
    x_test, y_test, test_size=0.5, random_state=9)
print(f'train: {x_train.shape, y_train.shape}\nval: {x_val.shape, y_val.shape}\ntest: {x_test.shape, y_test.shape}\n')
# Out:
# train: ((10621, 44100), (10621,))
# val: ((1328, 44100), (1328,))
# test: ((1328, 44100), (1328,))

# %%
x_train_uk, x_val_uk, y_train_uk, y_val_uk = train_test_split(
    uk_values, uk_labels, test_size=0.3, random_state=3)
print(f'train: {x_train_uk.shape, y_train_uk.shape}\nval: {x_val_uk.shape, y_val_uk.shape}\n')
# Out:
# train: ((77, 44100), (77,))
# val: ((34, 44100), (34,))

# %% [markdown]
# ## Save features

# %%
import extraction_utils as eu

# %%
eu.extract_mels(x_train, y_train, path='./features/features-train-no-uk-mel-v4.csv', augment=True)
# Out:
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# ...

# %%
eu.extract_mels(x_val, y_val, path='./features/features-val-no-uk-mel-v4.csv', augment=False)
# Out:
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# ...

# %%
eu.extract_mels(x_test, y_test, path='./features/features-test-no-uk-mel-v4.csv', augment=False)
# Out:
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# ...

# %%
eu.extract_mels(x_train_uk, y_train_uk, path='./features/features-train-uk-new-mel-v4.csv', augment=False)
# Out:
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)

# %%
eu.extract_mels(uk_test_values, uk_test_labels, path='./features/features-test-uk-new-mel-v4.csv', augment=False, shuffle=False)
# Out:
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
