# %%
import re

import pandas as pd
import numpy as np

from bs4 import BeautifulSoup
from lxml import html
import requests

# %%
movies_url_p1 = 'https://www.imdb.com/list/ls022298534/'
movies_url_p2 = 'https://www.imdb.com/list/ls022298534/?page=2'
movies_url_p3 = 'https://www.imdb.com/list/ls022298534/?page=3'
movies_df = pd.read_csv('../movies_dubbed.csv')
content1 = ''
content2 = ''
content3 = ''

# %%
movies_df.head()
# Out:
#                  film  dubbed
# 0  american history x   False
# 1    bicentennial man   False
# 2              casinò   False
# 3   good will hunting   False
# 4               crash   False

# %%
# response1 = requests.get(movies_url_p1)
# response2 = requests.get(movies_url_p2)
# response3 = requests.get(movies_url_p3)


# soup = BeautifulSoup(response.content, 'html.parser')

# list = soup.body.find_all('h3', 'lister-item-header')
# list = soup.body.descendants.h3('lister-item-header')

# %%
# if response1.status_code == 200 and response2.status_code == 200 and response3.status_code == 200:
#     print('Success!')
#     content1 = response1.content.decode('utf-8').lower()
#     content2 = response2.content.decode('utf-8').lower()
#     content3 = response3.content.decode('utf-8').lower()
# else:
#     print('An error has occurred')

# %%
with open('./url1.html') as f:
    content1 = f.read().lower()

with open('./url2.html') as f:
    content2 = f.read().lower()

with open('./url3.html') as f:
    content3 = f.read().lower()

# %%
for index, row in movies_df.iterrows():
    if (content1.find(row['film']) != -1 or 
        content2.find(row['film']) != -1 or 
        content3.find(row['film']) != -1
        ):

        movies_df.loc[index, 'dubbed'] = True

# %%
movies_df
# Out:
#                                film  dubbed
# 0                american history x   False
# 1                  bicentennial man   False
# 2                            casinò   False
# 3                 good will hunting   False
# 4                             crash    True
# 5                        antichrist   False
# 6                  bicentennian man   False
# 7               million dollar baby   False
# 8                my life without me   False
# 9                        the others   False
# 10                   cinderella man   False
# 11                finding neverland   False
# 12         intelligenza artificiale   False
# 13                        the hours   False
# 14                             saw3   False
# 15                     notting hill   False
# 16                     falling down   False
# 17                   the impossible   False
# 18                     side effects   False
# 19                             hook   False
# ...

# %%
movies_df.loc[movies_df.dubbed == True]
# Out:
#                      film  dubbed
# 4                   crash    True
# 20            poltergeist    True
# 43                titanic    True
# 44  the devil wears prada    True

# %%
movies_df.to_csv('../movies_dubbed.csv', mode='w', index=False, sep=',')
